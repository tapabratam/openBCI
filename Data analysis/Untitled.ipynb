# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Sam final, 10,15,20.csv')

# %%
df = df[['first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'seventh', 'eighth', 'level']]
df.dropna(inplace=True)

# %%
df.tail()
# Out:
#           first    second     third    fourth     fifth     sixth   seventh  \
# 11258 -53749.55 -17598.71 -64047.04 -96633.43 -50037.55 -43425.01 -69242.77
# 11259 -53740.57 -17544.13 -64138.57 -96732.45 -50042.09 -43425.08 -69251.23
# 11260 -53895.73 -17743.46 -64295.66 -96950.71 -50048.95 -43430.76 -69266.73
# 11261 -53972.93 -17889.29 -64285.45 -96963.98 -50044.91 -43430.60 -69263.27
# 11262 -53897.59 -17826.21 -64142.96 -96815.64 -50035.92 -43430.73 -69247.22
#
#          eighth    level
# 11258 -77003.10  excited
# 11259 -77014.56  excited
# 11260 -77042.19  excited
# 11261 -77039.13  excited
# 11262 -77023.95  excited

# %%
sns.distplot(df['sixth'])

# %%
sns.jointplot(x='first',y='second',data=df,kind='scatter')

# %%
sns.pairplot(df, hue='level')

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df.drop('level',axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features = scaler.transform(df.drop('level',axis=1))

# %%
df_feat = test_df[['first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'seventh', 'eighth']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_features,test_df['level'],
                                                    test_size=0.30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-175-e62c5fa44fc8> in <module>()
#       1 X_train, X_test, y_train, y_test = train_test_split(scaled_features,test_df['level'],
# ----> 2                                                     test_size=0.30)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2013         test_size = 0.25
#    2014
# -> 2015     arrays = indexable(*arrays)
#    2016
#    2017     if shuffle is False:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     196         else:
#     197             result.append(np.array(X))
# --> 198     check_consistent_length(*result)
#     199     return result
#     200
#
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[   0    0 3654]
#  [   0    0    0]
#  [   0   25 4680]]

# %%
print(classification_report(y_test,pred))
# Out:
#              precision    recall  f1-score   support
#
# concentrate       0.00      0.00      0.00      3654
# contentrate       0.00      0.00      0.00         0
#     excited       0.56      0.99      0.72      4705
#
# avg / total       0.32      0.56      0.40      8359
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# ### ####

# %%
test_df = pd.read_csv('Avijit sir final 10,15,19 - Copy.csv')

# %%
test_df = test_df[['first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'seventh', 'eighth', 'level']]
test_df.dropna(inplace=True)

# %%
sns.pairplot(test_df, hue='level')

# %% [markdown]
# # test

# %%
X_test = df[['first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'seventh', 'eighth']]

# %%
y_test = df[['level']]

# %%
df = pd.read_csv('Sumanjit final 10,15,20.csv')
df = df[['first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'seventh', 'eighth', 'level']]
df.dropna(inplace=True)

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.to_csv('out.csv')

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df_level = df[['level']]

# %%
df['level'] = df_level

# %%
df
# Out:
#          first    second     third     fourth     fifth     sixth   seventh  \
# 0    -45743.60 -48928.84 -50486.24 -119523.05 -61480.80 -63123.67 -47760.65
# 1    -46479.49 -50174.19 -51731.88 -120786.86 -62757.17 -64504.90 -48655.84
# 2    -46193.70 -49628.83 -52015.59 -120282.82 -62233.04 -63938.13 -48439.52
# 3    -46764.45 -50574.78 -53447.45 -121228.30 -63213.91 -65004.17 -49106.27
# 4    -46587.34 -50278.91 -51961.66 -120825.37 -62840.86 -64574.01 -48739.41
# 5    -46052.23 -49400.04 -52727.25 -120086.98 -62027.12 -63751.40 -48523.64
# 6    -45714.50 -48870.79 -51221.14 -119547.67 -61507.46 -63157.36 -47932.51
# 7    -46815.48 -50701.60 -53550.62 -121409.04 -63376.63 -65155.76 -49240.22
# 8    -46845.32 -50717.13 -52598.97 -121407.43 -63386.01 -65176.97 -49159.33
# 9    -46794.65 -50621.54 -53112.82 -121308.32 -63287.15 -65071.89 -49164.16
# 10   -46719.32 -50495.70 -53113.87 -121173.18 -63140.59 -64936.78 -49055.59
# ...
